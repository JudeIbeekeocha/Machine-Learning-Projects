# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

from IPython import display
display.set_matplotlib_formats('svg') # Improve matplotlib visual quality
# Out:
# <ipython-input-2-aaf946350145>:13: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg') # Improve matplotlib visual quality

# %% [markdown]
# #Objective: Use a Random Forest classification model to identify when a company might go bankrupt.

# %% [markdown]
# ##Importing the Dataset

# %%
# !wget https://raw.githubusercontent.com/JudeIbeekeocha/Database_Repo/main/data%202.csv
# Out:
# --2024-07-21 15:34:28--  https://raw.githubusercontent.com/JudeIbeekeocha/Database_Repo/main/data%202.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11456101 (11M) [text/plain]
# Saving to: ‘data 2.csv’
#
# data 2.csv          100%[===================>]  10.92M  --.-KB/s    in 0.1s
#
# 2024-07-21 15:34:29 (91.9 MB/s) - ‘data 2.csv’ saved [11456101/11456101]

# %%
data = pd.read_csv('data 2.csv').iloc[:, :11] # Using the first 11 values

# %%
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...                                       ...
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# 6817                                           0.554045
# 6818                                           0.549548
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 0                    0.601457                      0.601457
# 1                    0.610235                      0.610235
# 2                    0.601450                      0.601364
# 3                    0.583541                      0.583541
# 4                    0.598783                      0.598783
# ...                       ...                           ...
# 6814                 0.604455                      0.604462
# 6815                 0.598308                      0.598308
# 6816                 0.610444                      0.610213
# 6817                 0.607850                      0.607850
# 6818                 0.627409                      0.627409
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                   0.998969                    0.796887
# 1                   0.998946                    0.797380
# 2                   0.998857                    0.796403
# 3                   0.998700                    0.796967
# 4                   0.998973                    0.797366
# ...                      ...                         ...
# 6814                0.998992                    0.797409
# 6815                0.998992                    0.797414
# 6816                0.998984                    0.797401
# 6817                0.999074                    0.797500
# 6818                0.998080                    0.801987
#
#        After-tax net Interest Rate  \
# 0                         0.808809
# 1                         0.809301
# 2                         0.808388
# 3                         0.808966
# 4                         0.809304
# ...                            ...
# 6814                      0.809331
# 6815                      0.809327
# 6816                      0.809317
# 6817                      0.809399
# 6818                      0.813800
#
#        Non-industry income and expenditure/revenue  \
# 0                                         0.302646
# 1                                         0.303556
# 2                                         0.302035
# 3                                         0.303350
# 4                                         0.303475
# ...                                            ...
# 6814                                      0.303510
# 6815                                      0.303520
# 6816                                      0.303512
# 6817                                      0.303498
# 6818                                      0.313415
#
#        Continuous interest rate (after tax)
# 0                                  0.780985
# 1                                  0.781506
# 2                                  0.780284
# 3                                  0.781241
# 4                                  0.781550
# ...                                     ...
# 6814                               0.781588
# 6815                               0.781586
# 6816                               0.781546
# 6817                               0.781663
# 6818                               0.786079
#
# [6819 rows x 11 columns]

# %% [markdown]
# ##Data Analysis

# %%
data.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# 50%                                   0.559802
# 75%                                   0.589157
# max                                   1.000000
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        6819.000000
# mean                                            0.553589
# std                                             0.061595
# min                                             0.000000
# 25%                                             0.527277
# 50%                                             0.552278
# 75%                                             0.584105
# max                                             1.000000
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              6819.000000                   6819.000000
# mean                  0.607948                      0.607929
# std                   0.016934                      0.016916
# min                   0.000000                      0.000000
# 25%                   0.600445                      0.600434
# 50%                   0.605997                      0.605976
# 75%                   0.613914                      0.613842
# max                   1.000000                      1.000000
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             6819.000000                 6819.000000
# mean                 0.998755                    0.797190
# std                  0.013010                    0.012869
# min                  0.000000                    0.000000
# 25%                  0.998969                    0.797386
# 50%                  0.999022                    0.797464
# 75%                  0.999095                    0.797579
# max                  1.000000                    1.000000
#
#         After-tax net Interest Rate  \
# count                   6819.000000
# mean                       0.809084
# std                        0.013601
# min                        0.000000
# 25%                        0.809312
# 50%                        0.809375
# 75%                        0.809469
# max                        1.000000
#
#         Non-industry income and expenditure/revenue  \
# count                                   6819.000000
# mean                                       0.303623
# std                                        0.011163
# min                                        0.000000
# 25%                                        0.303466
# 50%                                        0.303525
# 75%                                        0.303585
# max                                        1.000000
#
#         Continuous interest rate (after tax)
# count                            6819.000000
# mean                                0.781381
# std                                 0.012679
# min                                 0.000000
# 25%                                 0.781567
# 50%                                 0.781635
# 75%                                 0.781735
# max                                 1.000000

# %%
# No null values
data.isnull().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#  Realized Sales Gross Margin                                0
#  Operating Profit Rate                                      0
#  Pre-tax net Interest Rate                                  0
#  After-tax net Interest Rate                                0
#  Non-industry income and expenditure/revenue                0
#  Continuous interest rate (after tax)                       0
# dtype: int64

# %%
print('The amount of bankrupt companies:', (data['Bankrupt?'] == 1).sum())
print('The amount of non-bankrupt companies:', (data['Bankrupt?'] == 0).sum())
# Out:
# The amount of bankrupt companies: 220
# The amount of non-bankrupt companies: 6599

# %%
data['Bankrupt?'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Bankrupt?'>

# %%
fig, ax = plt.subplots(1, len(data.columns) - 1, sharey=True, figsize = (15, 5))

for i, col in enumerate([i for i in data.columns if i != 'Bankrupt?']):
  ax[i].hist(data[col], bins = 10)

# %%
fig, ax = plt.subplots(1, len(data.columns) - 1, sharey=True, figsize = (15, 5))

for i, col in enumerate([i for i in data.columns if i != 'Bankrupt?']):
  ax[i].boxplot(data[col])

# %% [markdown]
# ##The extremely unbalanced dataset would make the Random Forest unable to learn properly from the dataset, so we would have to resample and balance the dataset.

# %% [markdown]
# ##Data Preprocessing

# %%
df_majority = data[data['Bankrupt?'] == 0]
df_minority = data[data['Bankrupt?'] == 1]

# %%
print(len(df_majority))
print(len(df_minority))
# Out:
# 6599
# 220

# %%
# Downsize the Majority class

df_downsize = resample( # resample shuffles the data by default which is good
                      df_majority,
                      replace=False,
                      n_samples=len(df_minority), #downsizing to the length of the minority
                      random_state= 0
)

# %%
len(df_downsize)
# Out:
# 220

# %%
# Combining the downsized and minority
df_balanced = pd.concat([df_downsize, df_minority])
df_balanced
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 6818          0                                           0.493053
# 613           0                                           0.527568
# 3301          0                                           0.560328
# 6479          0                                           0.522157
# 6216          0                                           0.530298
# ...         ...                                                ...
# 6591          1                                           0.418515
# 6640          1                                           0.196802
# 6641          1                                           0.337640
# 6642          1                                           0.340028
# 6728          1                                           0.492176
#
#        ROA(A) before interest and % after tax  \
# 6818                                 0.570105
# 613                                  0.603958
# 3301                                 0.633450
# 6479                                 0.593000
# 6216                                 0.563127
# ...                                       ...
# 6591                                 0.433984
# 6640                                 0.211023
# 6641                                 0.254307
# 6642                                 0.344636
# 6728                                 0.544320
#
#        ROA(B) before interest and depreciation after tax  \
# 6818                                           0.549548
# 613                                            0.570587
# 3301                                           0.622517
# 6479                                           0.581134
# 6216                                           0.576905
# ...                                                 ...
# 6591                                           0.461427
# 6640                                           0.221425
# 6641                                           0.378446
# 6642                                           0.380213
# 6728                                           0.533326
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 6818                 0.627409                      0.627409
# 613                  0.617204                      0.617204
# 3301                 0.594683                      0.594683
# 6479                 0.640568                      0.640568
# 6216                 0.623805                      0.623805
# ...                       ...                           ...
# 6591                 0.612750                      0.612750
# 6640                 0.598056                      0.598056
# 6641                 0.590842                      0.590842
# 6642                 0.581466                      0.581466
# 6728                 0.618105                      0.618105
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 6818                0.998080                    0.801987
# 613                 0.999137                    0.797677
# 3301                0.998961                    0.797430
# 6479                0.999152                    0.797580
# 6216                0.999136                    0.797539
# ...                      ...                         ...
# 6591                0.998864                    0.796902
# 6640                0.998933                    0.796144
# 6641                0.998869                    0.796943
# 6642                0.998372                    0.796292
# 6728                0.999083                    0.797456
#
#        After-tax net Interest Rate  \
# 6818                      0.813800
# 613                       0.809534
# 3301                      0.809354
# 6479                      0.809498
# 6216                      0.809453
# ...                            ...
# 6591                      0.808857
# 6640                      0.808149
# 6641                      0.808897
# 6642                      0.808283
# 6728                      0.809338
#
#        Non-industry income and expenditure/revenue  \
# 6818                                      0.313415
# 613                                       0.303675
# 3301                                      0.303611
# 6479                                      0.303473
# 6216                                      0.303436
# ...                                            ...
# 6591                                      0.302892
# 6640                                      0.301423
# 6641                                      0.302953
# 6642                                      0.302857
# 6728                                      0.303401
#
#        Continuous interest rate (after tax)
# 6818                               0.786079
# 613                                0.781729
# 3301                               0.781615
# 6479                               0.781764
# 6216                               0.781724
# ...                                     ...
# 6591                               0.781254
# 6640                               0.780388
# 6641                               0.781340
# 6642                               0.780733
# 6728                               0.781598
#
# [440 rows x 11 columns]

# %%
df_balanced.describe()
# Out:
#         Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  440.000000                                         440.000000
# mean     0.500000                                           0.462363
# std      0.500569                                           0.088018
# min      0.000000                                           0.000000
# 25%      0.000000                                           0.431227
# 50%      0.500000                                           0.473553
# 75%      1.000000                                           0.505984
# max      1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                               440.000000
# mean                                  0.508357
# std                                   0.105127
# min                                   0.000000
# 25%                                   0.474651
# 50%                                   0.534916
# 75%                                   0.562882
# max                                   0.947067
#
#         ROA(B) before interest and depreciation after tax  \
# count                                         440.000000
# mean                                            0.507994
# std                                             0.094296
# min                                             0.000000
# 25%                                             0.474289
# 50%                                             0.523636
# 75%                                             0.556226
# max                                             0.957760
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count               440.000000                    440.000000
# mean                  0.603674                      0.603682
# std                   0.015131                      0.015105
# min                   0.532906                      0.532906
# 25%                   0.596717                      0.596870
# 50%                   0.601864                      0.601868
# 75%                   0.610307                      0.610244
# max                   0.665151                      0.665151
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count              440.000000                  440.000000
# mean                 0.998874                    0.797038
# std                  0.000540                    0.002312
# min                  0.991888                    0.757216
# 25%                  0.998855                    0.797107
# 50%                  0.998968                    0.797374
# 75%                  0.999042                    0.797477
# max                  0.999534                    0.801987
#
#         After-tax net Interest Rate  \
# count                    440.000000
# mean                       0.808907
# std                        0.003003
# min                        0.761550
# 25%                        0.809046
# 50%                        0.809301
# 75%                        0.809392
# max                        0.813800
#
#         Non-industry income and expenditure/revenue  \
# count                                    440.000000
# mean                                       0.303109
# std                                        0.003686
# min                                        0.235090
# 25%                                        0.303271
# 50%                                        0.303466
# 75%                                        0.303536
# max                                        0.313415
#
#         Continuous interest rate (after tax)
# count                             440.000000
# mean                                0.781226
# std                                 0.002265
# min                                 0.742704
# 25%                                 0.781293
# 50%                                 0.781541
# 75%                                 0.781648
# max                                 0.786079

# %%
x = df_balanced.drop('Bankrupt?', axis=1)
y = df_balanced['Bankrupt?']

# %% [markdown]
# ##Splitting the dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=True, random_state=2)

# %%
scaled = StandardScaler()
x_s_train = scaled.fit_transform(x_train)
x_s_test = scaled.transform(x_test)

# %%
x_train
# Out:
#        ROA(C) before interest and depreciation before interest  \
# 2899                                           0.484620
# 6202                                           0.567104
# 4808                                           0.558816
# 2991                                           0.550773
# 4071                                           0.374202
# ...                                                 ...
# 1751                                           0.369766
# 628                                            0.475308
# 3832                                           0.412226
# 4567                                           0.515770
# 6722                                           0.502072
#
#        ROA(A) before interest and % after tax  \
# 2899                                 0.534889
# 6202                                 0.606411
# 4808                                 0.621784
# 2991                                 0.580680
# 4071                                 0.433330
# ...                                       ...
# 1751                                 0.387484
# 628                                  0.539850
# 3832                                 0.474651
# 4567                                 0.567052
# 6722                                 0.555168
#
#        ROA(B) before interest and depreciation after tax  \
# 2899                                           0.532148
# 6202                                           0.600996
# 4808                                           0.603458
# 2991                                           0.588682
# 4071                                           0.418705
# ...                                                 ...
# 1751                                           0.412924
# 628                                            0.527384
# 3832                                           0.467584
# 4567                                           0.560576
# 6722                                           0.546764
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 2899                 0.604448                      0.604448
# 6202                 0.614321                      0.614379
# 4808                 0.605522                      0.605522
# 2991                 0.611770                      0.611770
# 4071                 0.598416                      0.598488
# ...                       ...                           ...
# 1751                 0.532906                      0.532906
# 628                  0.605796                      0.605796
# 3832                 0.599562                      0.599562
# 4567                 0.606783                      0.606776
# 6722                 0.597025                      0.597032
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 2899                0.998958                    0.797380
# 6202                0.999154                    0.797639
# 4808                0.999102                    0.797638
# 2991                0.999136                    0.797548
# 4071                0.998871                    0.797194
# ...                      ...                         ...
# 1751                0.994729                    0.792397
# 628                 0.998980                    0.797378
# 3832                0.998884                    0.797225
# 4567                0.999018                    0.797469
# 6722                0.998961                    0.797459
#
#        After-tax net Interest Rate  \
# 2899                      0.809307
# 6202                      0.809490
# 4808                      0.809510
# 2991                      0.809414
# 4071                      0.809133
# ...                            ...
# 1751                      0.804618
# 628                       0.809301
# 3832                      0.809187
# 4567                      0.809374
# 6722                      0.809356
#
#        Non-industry income and expenditure/revenue  \
# 2899                                      0.303532
# 6202                                      0.303574
# 4808                                      0.303680
# 2991                                      0.303452
# 4071                                      0.303388
# ...                                            ...
# 1751                                      0.303673
# 628                                       0.303482
# 3832                                      0.303414
# 4567                                      0.303561
# 6722                                      0.303662
#
#        Continuous interest rate (after tax)
# 2899                               0.781564
# 6202                               0.781764
# 4808                               0.781784
# 2991                               0.781730
# 4071                               0.781367
# ...                                     ...
# 1751                               0.776654
# 628                                0.781558
# 3832                               0.781432
# 4567                               0.781638
# 6722                               0.781617
#
# [352 rows x 10 columns]

# %% [markdown]
# ##EDA

# %%
df_balanced['Bankrupt?'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Bankrupt?'>

# %%
fig, ax = plt.subplots(1, len(df_balanced.columns) - 1, sharey=True, figsize = (15, 5))

for i, col in enumerate(x.columns):
  ax[i].hist(df_balanced[col], bins = 10)

# %%
fig, ax = plt.subplots(1, len(df_balanced.columns) - 1, sharey=True, figsize = (15, 5))

for i, col in enumerate(x.columns):
  ax[i].boxplot(df_balanced[col])

# %%
# Train set

fig, ax = plt.subplots(1, len(df_balanced.columns) - 1, sharey=True, figsize = (15, 5))

for i, col in enumerate(x.columns):
  ax[i].boxplot(x_s_train[i])

# %% [markdown]
# ##Training the Decision Tree Model

# %%
rf = RandomForestClassifier(criterion='entropy', random_state=6) #6
rf.fit(x_s_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=6)

# %% [markdown]
# ##Predicting the Test set

# %%
pred = rf.predict(x_s_test)

df = pd.DataFrame({'True': y_test, "predictions":pred, 'Result':y_test + pred})
df #0 or 2 is a correct prediction
# Out:
#       True  predictions  Result
# 1333     0            0       0
# 1446     1            1       2
# 4318     0            1       1
# 3711     0            0       0
# 3183     1            1       2
# ...    ...          ...     ...
# 1867     1            1       2
# 1962     0            1       1
# 4788     1            1       2
# 2002     1            1       2
# 474      0            0       0
#
# [88 rows x 3 columns]

# %% [markdown]
# ##Results

# %%
print(accuracy_score(y_test, pred))
# Out:
# 0.875

# %%
_ = ConfusionMatrixDisplay.from_estimator(rf, x_s_test, y_test)
